# %%
f0=[0.5,0.5,0.5,0.51]
r0=[0.5,2.5,4.5,4.5]
for i in range(0, 4):
    print('\n')
    f=f0[i]
    r=r0[i]
    print('r=',r ,'f=',f,'\n')
    for j in range(1, 11):
        f=r*f*(1-f)
        print('f_%d = %f'%(j,f))
# Out:
# r= 0.5 f= 0.5
#
# f_1 = 0.125000
# f_2 = 0.054688
# f_3 = 0.025848
# f_4 = 0.012590
# f_5 = 0.006216
# f_6 = 0.003089
# f_7 = 0.001540
# f_8 = 0.000769
# f_9 = 0.000384
# f_10 = 0.000192
#
#
# r= 2.5 f= 0.5
#
# f_1 = 0.625000
# f_2 = 0.585938
# f_3 = 0.606537
# f_4 = 0.596625
# f_5 = 0.601659
# f_6 = 0.599164
# f_7 = 0.600416
# f_8 = 0.599791
# f_9 = 0.600104
# f_10 = 0.599948
#
#
# r= 4.5 f= 0.5
#
# f_1 = 1.125000
# f_2 = -0.632812
# f_3 = -4.649689
# f_4 = -118.211823
# f_5 = -63415.110756
# f_6 = -18096928592.854885
# f_7 = -1473744710308435329024.000000
# f_8 = -9773655620229423120655354920789396517027840.000000
# f_9 = -429859548822789819131034092991151387509184499062888717227552864695314714926550498672640.000000
# f_10 = -831506542713595934567149371579456604878928039370000409221279371549010386912654879699379404039062699032503760546205316515170893492655621917023102723354773544463889572374249472.000000
#
#
# r= 4.5 f= 0.51
#
# f_1 = 1.124550
# f_2 = -0.630282
# f_3 = -4.623920
# ...
